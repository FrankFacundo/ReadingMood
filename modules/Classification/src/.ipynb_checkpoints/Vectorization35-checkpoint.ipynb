# %%
# coding: ANSI

from collections import Counter
from nltk.stem import SnowballStemmer as stm
from nltk.stem import WordNetLemmatizer 
import nltk
import time as cl
from sklearn.feature_extraction.text import TfidfVectorizer
import glob
import os as os
from collections import Counter
# nltk.download('all')
# vocab = eval(readtxt("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Vocabulaire.txt"))
#Obtention de vocab dans la rubrique consacrée au vocabulaire

### Affichage du fichier

# %%
from nltk.tokenize import WordPunctTokenizer

    

def tokenize(file):
    word_punct_tokenizer = WordPunctTokenizer()
    with open(file, "r") as file:
            s = file.read()
            wordsList = word_punct_tokenizer.tokenize(s)
            WL=[]
            punctEscape = ',.:;.?,?!()-&éà%$€£<>[]+^¨*ù/â|…1234567890–‘’”“#'
            punctEscape = punctEscape + "\"" + "\\"
            for word in wordsList:
                mark = True
                for punct in punctEscape:
                    if punct in word:
                        mark = False
                if mark:
                    WL.append(word)
    return(WL)

# %% [markdown]
# ## Tokenisation du texte

# %% [markdown]
# ### Lemmatization de la liste de string

# %%
# Normalise les mots en leurs radicaux
def lemmatization(texte):    # texte est une liste de str
    wordnet_lemmatizer = WordNetLemmatizer()
    Lem=wordnet_lemmatizer.lemmatize
    snowball_stemmer = stm("english")
    Normal=[]
    
    
    for mot in texte:
        if snowball_stemmer.stem(mot) != mot:
            Normal.append(snowball_stemmer.stem(mot))
        elif Lem(mot, pos = 'n') != mot:
            Normal.append(Lem(mot, pos = 'n'))
        elif Lem(mot, pos = 'v')!=mot:
            Normal.append(Lem(mot, pos = 'v'))
        elif Lem(mot, pos = 'a') != mot:
            Normal.append(Lem(mot, pos = 'a'))
        else:
            Normal.append(mot)
    return Normal       # List de str

# %% [markdown]
# ## Problèmes des Stop Words (SW)

# %% [markdown]
# ### Création d'une liste de SW

# %%
# fileSW = open("/Users/NAIT/Desktop/stopWords.txt", "r")
fileSW=open("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Classification\stopWords.txt","r")
lines = fileSW.readlines()

stopWords = []
for word in lines:
    word = word.rstrip('\n')
    stopWords.append(word)
#print(stopWords)

# %% [markdown]
# ### Élimination des SW

# %%
# Transforme une liste de str en une liste de str sans les SW
def StopWordsElimination(list):
    List = [word for word in list if word not in stopWords or word.isdigit() == True]
    finalString =""
    for a in List:
        finalString = finalString + " " + a
    return finalString

# %% [markdown]
# ## Définition d'une norme

# %%
def Dico():
    Vocabstr = readtxt("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Textes Ambiance\Vocabulaire.txt")
    Vocab = eval(Vocabstr)
    prepDico = []
    for mot in Vocab:
        prepDico.append([mot,0])
    dico = dict(prepDico)
    return dico,Vocab

def comptage(texte):
    
    dictionnaire, Vocab= Dico()
    
    for mot in texte:
        if mot in dictionnaire:
            dictionnaire[mot]+=1
            
            
    n = len(dictionnaire)
    vecteur = np.zeros(n)

    for i in range(n):    

        vecteur[i] = dictionnaire[Vocab[i]]

    return vecteur

def TFIDF(corpus, vocab):
    vectorizer = TfidfVectorizer(vocabulary=vocab)
    response = vectorizer.fit_transform(corpus)
    CorpusVect = response.toarray()
    return CorpusVect

# %% [markdown]
# ### On a besoin d'une liste de mots pour initialiser la TFIDF avec l'attribut vocab. Ce vocabulaire sera récupéré en annexe dans une fonction Vocabulary()

# %% [markdown]
# ## Conclusion

# %%
def Vectorize(fichiertxt):          # Vectorisation d'1 fichier texte
    wordsList = tokenize(fichiertxt)
    Normal = lemmatization(wordsList)
    ListeReduite = StopWordsElimination(Normal)
    return ListeReduite #"str"
    

def VectorizationOfDataSet():   # La liste de tous les textes
    corpus = []
    adresseDocAmb = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set"
    LAmbiances = os.listdir(adresseDocAmb)
    
    for ambiance in LAmbiances:
        PtrAmbFold = os.listdir("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance)
        
        for PtrFile in PtrAmbFold:

            AdresseText = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance + "\\" + PtrFile
            corpus.append(Vectorize(AdresseText))

    return corpus

def VectorisationAmb(): # Vectorisation des textes d'ambiances
    c1 = cl.clock()
    def VectorizationOfDataSetTMP():   # La liste de tous les textes
        corpus = []
        adresseDocAmb = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set"
        LAmbiances = os.listdir(adresseDocAmb)
        Lid = []
        for ambiance in LAmbiances:
            PtrAmbFold = os.listdir("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance)
            n = 0
            for PtrFile in PtrAmbFold:
    
                AdresseText = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance + "\\" + PtrFile
                corpus.append(Vectorize(AdresseText))
                n+=1
            Lid.append((ambiance,n))
        return corpus,Lid
    
    corpus,ident = VectorizationOfDataSetTMP()
    reponse = TFIDF(corpus,vocab), ident
    c2 = cl.clock()
    print(c2-c1)    # Petite estimation du temps que ça prend
    return reponse
    # reponse = LVecteurs, ident
    # ident est la liste des couples (Ambiance, nbTextes de l'ambiance)

def Vectorisation(LAdresseText):
    LRed = []
    for AdresseText in LAdresseText:
        LRedi = Vectorize(AdresseText)
        LRed.append(LRedi)
    return TFIDF(LRed,vocab)

# %% [markdown]
# ## Réduction de dimensions : PCA

# %%
from sklearn.decomposition import PCA
import numpy as np


def ReductionDim(X,n):
    c1 = cl.clock()
    pca = PCA(n_components = n)
    pca.fit(X)
    Y = X.copy()
    Transformé = pca.transform(Y)
    c2 = cl.clock()
    print(c2-c1)
    return Transformé,pca

# %% [markdown]
# ## Test de la vectorisation

# %%
def TestPCA():
    Vec = Vectorisation()
    V = Vec.copy()
    n = 30
    return ReductionDim(V,n)

# %% [markdown]
# ## Annexes

# %%
##### Vocabulaire



def Vocabulary():   # Vectorisation de l'ensemble du corpus

    def EnsembleDesTextes():   # La liste de tous les textes
        corpus = []
        adresseDocAmb = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set"
        LAmbiances = os.listdir(adresseDocAmb)
        
        for ambiance in LAmbiances:
            PtrAmbFold = os.listdir("C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance)
            
            for PtrFile in PtrAmbFold:
    
                AdresseText = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Data Set" + "\\" + ambiance + "\\" + PtrFile
                vec = Vectorize(AdresseText)
                corpus.append(vec)
    
        return corpus
    

    def tokenize1txt(brut):

        word_punct_tokenizer = WordPunctTokenizer()
        wordsList = word_punct_tokenizer.tokenize(brut)
        wordsList = [word for word in wordsList if word not in ["'",".",":",";",'."','?"',",","?","!","(",")","-",'"'] ]
        return(wordsList)
        


    
    def EnsembleMots(texte): #type(texte)=list(str)
        Dico=Counter(texte)   # Le dico
        Différents = []
        while Dico != Counter():
            Différents.append(Dico.popitem()[0])
        return sorted(Différents)
    
    c1 = cl.clock()
    Corp = EnsembleDesTextes()
    brut = " "
    for texte in Corp:
        brut = brut + " " + texte
    SimpleTot = tokenize1txt(brut)
    Vocabulaire = EnsembleMots(SimpleTot)
    
    c2 = cl.clock()
    print(c2-c1)
    return Vocabulaire
    
def NvTexte(texte,AdresseCible):
    fichiertxt = open(AdresseCible,mode="x")
    fichiertxt.write(texte)
    fichiertxt.close()
    
def NvGROSTexte(Tableau,AdresseCible):
    fichiertxt = open(AdresseCible,mode="x")
    fichiertxt.write("[")
    
    for i in range(len(Tableau)):
        
        if i != 0:
            fichiertxt.write(",")
        fichiertxt.write("[")
        
        for j in range(len(Tableau[i])):
            if j != 0:
                fichertxt.write(",")
            try:
                fichiertxt.write(str(Tableau[i,j]))
            except:
                return i,j
        
        fichiertxt.write("]")
    
    fichiertxt.write("]")
    fichiertxt.close()
    
"""
vocab = Vocabulary()
AdresseCible = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Vocabulaire.txt"
NvTexte(str(vocab),AdresseCible)
"""    

#################################################################################################################################

##### WebScraping: Constitution de la BDD d'ambiances

"""
Ces fonctions sont notamment adaptées à l'interface de Thierry Bécart.
On récupère les codes Source (codeS) de Descriptionari et on en extrait les textes.
On a effectivement remarqu" que sur ce site, les codes sources sont précédés de "data-writing-prompt=\"0\"><p>" et finissent par <p>

A chaque fois qu'un texte est récupéré, il est enregistré comme un fichier txt sur un dossier cible préexistant sous le format Ambiance[k]

"""

# Traduction d'un fichier en str
def readtxt(adresse):
        
    with open(adresse, "r") as file:
        s = file.read()
    return s
    


# Détection d'un texte à lire
def detectStart(codeS,i):
    n = len(codeS)
    motifStart = "data-writing-prompt=\"0\"><p>"
    if n-i > 27:
        Testé = codeS[i:i+27]
        if Testé == motifStart:
            return True
    return False

# Détection de fin de texte
def detectEnd(codeS,i):
    n = len(codeS)
    motifEnd = "</p>"
    if n-i >4:
        Testé = codeS[i:i+4]
        if Testé == motifEnd:
            return True
    return False

# Ecriture d'un texte
def Ecrit(codeS,i):
    j = 0
    T = ""
    while not(detectEnd(codeS,i+j)):
        T=T+codeS[i+j]
        j+=1
    return T

# Extraction des textes du code Source
def diviseTexte(codeS):
    Corpus = []
    i = 0
    n = len(codeS)
    while i!=n:
        if detectStart(codeS,i):
            i+=27
            Texte = Ecrit(codeS,i)
            Corpus.append(Texte)
            decal=len(Texte) + 4
            i += decal
        i+=1
    return Corpus

# Récupération des textes liés à 1 ambiance donnée
def Textes(Ambiance):
    folder = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Textes Ambiance" # L'adresse du dossier source
    adresse = folder + '\\' + Ambiance + "\\" + Ambiance + ".txt"   #Adresse du fichier texte contenant le code source
    return diviseTexte(readtxt(adresse))


# Création des fichiers Textes extraits des codes source
def Ecrituretxt(Ambiance,numero,texte):
    folder = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Textes Ambiance"
    adresse = folder + '\\' + Ambiance + "\\" + Ambiance+str(numero)+".txt"
    fichiertxt = open(adresse,mode="x")
    fichiertxt.write(texte)
    fichiertxt.close()
    # L'adresse finale est ~\Ambiance\Ambiance(numéro).txt
    
# Crée tous les fichiers textes d'une ambiance donnée
def AjoutAmbiance(Ambiance):
    c1 = cl.clock()
    corpusAmbiance = Textes(Ambiance)
    for i in range(len(corpusAmbiance)):
        Ecrituretxt(Ambiance,i,corpusAmbiance[i])
    c2 = cl.clock()
    print(c2-c1)

# Renvoie le nombre de fichiers textes d'une ambiance donnée
def NTextAmbiances(LAmbiances):
    LNtextes = []
    for Ambiance in LAmbiances:
        corpusAmbiance = Textes(Ambiance)
        LNtextes.append(len(corpusAmbiance))
    return LNtextes

# Renvoie une liste des listes de textes joints  une même ambiance
def Corpus(LAmbiances):
    corpus = []
    for Ambiance in LAmbiances:
        corpusAmbiance = Textes(Ambiance)
        corpus.append(corpusAmbiance)
    return corpus


AdresseVocab = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Vocabulaire.txt"
vocab = eval(readtxt(AdresseVocab))
# AdresseGITThierry ="C:\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5\Depotgit"
# AdresseVocabGIT = "pact35\modules\Classification\src\Vocabulaire.txt"


def EcritureGROStxt(adresse, Banque):
    c1 = cl.clock()
    folder = "C:\\Users\Thierry\Documents\Telecom ParisTech\PACT 3.5"
    direction = folder + '\\' + adresse + ".txt"
    fichiertxt = open(direction,mode="x")
    fichiertxt.write("[")

    for i1 in range(len(Banque)):
        if i1 == 0:
            fichiertxt.write("[")
        else:
            fichiertxt.write(",[")
            
        for i2 in range(len(Banque[i1])):
            if i2 == 0:
                fichiertxt.write("[")
            else:
                fichiertxt.write(",[")
                
            for i3 in range(len(Banque[i1][i2])):
                if i3 == 0:
                    fichiertxt.write("[")
                else:
                    fichiertxt.write(",[")
            
                for i4 in range(len(Banque[i1][i2][i3])):
                    if i4 != 0:
                        fichiertxt.write(",")
                    fichiertxt.write(str(Banque[i1][i2][i3][i4]))
                fichiertxt.write("]")
            fichiertxt.write("]")
        fichiertxt.write("]")
    fichiertxt.write("]")
    fichiertxt.close()
    c2 = cl.clock()
    print(c2-c1)
    # L'adresse finale est ~\Ambiance\Ambiance(numéro).txt

# %% [markdown]
# ## Liste des mots de vocabulaire à disposition pour notre classifieur

# %%
Vocab = ['aa', 'aadila', 'aaron', 'aback', 'abandon', 'abdomen', 'abduct', 'abid', 'abil', 'abject', 'abl', 'abnorm', 'aboard', 'abod', 'abomin', 'abound', 'abour', 'abov', 'abraham', 'abras', 'abroad', 'abrupt', 'absenc', 'absent', 'absolut', 'absorb', 'absorpt', 'abstract', 'absurd', 'abund', 'abus', 'aby', 'abysm', 'academ', 'academi', 'acajou', 'acceler', 'accent', 'accentu', 'accept', 'access', 'accid', 'accommod', 'accompani', 'accomplic', 'accomplish', 'accord', 'account', 'accross', 'accru', 'accumul', 'accur', 'accus', 'accustom', 'ace', 'ach', 'achiev', 'acid', 'acknowledg', 'acn', 'acorn', 'acquiesc', 'acquir', 'acr', 'acrid', 'acryl', 'action', 'activ', 'actor', '
ier', 'barter', 'base', 'basebal', 'basement', 'bash', 'basi', 'basic', 'basil', 'basin', 'bask', 'basket', 'basketbal', 'bass', 'bastard', 'bastion', 'bat', 'batch', 'bath', 'bathroom', 'batman', 'battalion', 'batter', 'batteri', 'battl', 'battlefield', 'battlement', 'batty', 'bay', 'bayonet', 'baysid', 'beach', 'beachsid', 'beacon', 'bead', 'beak', 'beaki', 'beam', 'bean', 'bear', 'bearabl', 'beard', 'beast', 'beat', 'beater', 'beatric', 'beauteous', 'beauti', 'becam', 'becaus', 'beckon', 'becom', 'bed', 'bedrock', 'bedroom', 'bedsid', 'bedsit', 'bedtim', 'bee', 'beech', 'beef', 'beefy', 'beelin', 'beep', 'beer', 'beetl', 'beeton', 'befal', 'befall', 'befor', 'befriend', 'beg', 'beget', 'begonia', 'behalf', 'behav', 'behaviour', 'behead', 'behemoth', 'behest', 'behold', 'beig', 'bejewel', 'belch', 'beleagu', 'belgian', 'belief', 'believ', 'belittl', 'bell', 'belli', 'bellow', 'belong', 'belov', 'belt', 'beluga', 'ben', 'bench', 'bend', 'beneath', 'benefactor', 'benefic', 'beneficiari', 'benefit', 'benevol', 'bengali', 'benign', 'benji', 'benni', 'bequeath', 'bereav', 'bereft', 'beribbon', 'bermuda', 'bernard', 'bernardino', 'berown', 'berri', 'besid', 'besieg', 'bespeckl', 'bespectacl', 'bespok', 'best', 'bestow', 'bet', 'betray', 'better', 'betti', 'beuti', 'bewar', 'bewild', 'bewitch', 'bias', 'bibl', 'bicycl', 'bid', 'big', 'bigotri', 'bike', 'biker', 'bile', 'bilingu', 'bill', 'billboard', 'billion', 'billionair', 'billow', 'biltmor', 'bin', 'binari', 'bind', 'binocular', 'bio', 'bioengin', 'biographi', 'biolog', 'biometr', 'biospher', 'biped', 'biplan', 'birch', 'bird', 'birdsong', 'biro', 'birth', 'birthday', 'birthright', 'biscayan', 'biscuit', 'bit', 'bite', 'bitter', 'bizarr', 'black', 'blackberri', 'blackbird', 'blacken', 'blackmail', 'blackout', 'blacksmith', 'blade', 'blame', 'blanch', 'bland', 'blank', 'blanket', 'blare', 'blast', 'blatant', 'blather', 'blaze', 'blazingstar', 'blazon', 'bleach', 'bleacher', 'bleak', 'bleari', 'bleed', 'blemish', 'blend', 'bless', 'bleu', 'blind', 'blindfold', 'blink', 'bliss', 'blister', 'blizzard', 'blob', 'block', 'blog', 'bloke', 'blond', 'bloo', 'blood', 'bloodi', 'bloodlust', 'bloodsh', 'bloodshot', 'bloodstain', 'bloom', 'blossom', 'blot', 'blotch', 'blotchi', 'blous', 'blow', 'blower', 'blu', 'bludger', 'blue', 'bluebel', 'blueberri', 'bluff', 'bluish', 'blunt', 'blur', 'blurri', 'blurt', 'blush', 'bluster', 'blusteri', 'bmi', 'boar', 'board', 'boarder', 'boardwalk', 'boat', 'bob', 'bodi', 'bodiam', 'bodywork', 'boe', 'bog', 'bogey', 'boggi', 'boil', 'boister', 'bold', 'bole', 'bollard', 'bolt', 'bomb', 'bombard', 'bomber', 'bond', 'bondag', 'bone', 'bonfir', 'boni', 'bonnet', 'bonni', 'bonsai', 'bonus', 'boo', 'boob', 'book', 'bookcas', 'booklet', 'bookshelf', 'boom', 'boomtown', 'boost', 'boot', 'booth', 'bootheel', 'booz', 'border', 'bore', 'boreal', 'boredom', 'bori', 'born', 'borrow', 'bos', 'bosilem', 'boss', 'bosun', 'bother', 'bottl', 'bottom', 'bottomless', 'bough', 'boul', 'boulder', 'bounc', 'bouncer', 'bound', 'boundari', 'boundless', 'bounti', 'bouquet', 'bourn', 'bout', 'boutiqu', 'bow', 'bowel', 'bowl', 'bowsprit', 'box', 'boy', 'boyfriend', 'boyish', 'bozo', 'br', 'brace', 'bracelet', 'bracken', 'bracket', 'brackish', 'brad', 'bragi', 'braid', 'brain', 'brake', 'brambl', 'brampton', 'branch', 'brand', 'brandish', 'brandon', 'branston', 'brash', 'brass', 'brassi', 'brat', 'brave', 'braveri', 'brawl', 'brawn', 'bray', 'brazen', 'bread', 'breadcrumb', 'break', 'breakabl', 'breakdown', 'breakfast', 'breakthrough', 'breast', 'breath', 'breathi', 'breathless', 'breathtak', 'brecon', 'breech', 'breed', 'breek', 'breez', 'breezi', 'brentwood', 'brew', 'brianna', 'bribe', 'briberi', 'brick', 'brickwork', 'bride', 'bridesmaid', 'bridg', 'brie', 'briefli', 'bright', 'brighten', 'brillianc', 'brilliant', 'brim', 'brine', 'bring', 'bringer', 'brini', 'brisk', 'bristl', 'british', 'brittl', 'bro', 'broach', 'broad', 'broadcast', 'broil', 'broke', 'broker', 'brompton', 'bronco', 'bronz', 'brood', 'broodi', 'brook', 'broom', 'broomstick', 'broth', 'brother', 'brotherhood', 'brow', 'brown', 'browni', 'brownish', 'brows', 'bruis', 'brunett', 'brush', 'brusqu', 'brutal', 'bs', 'bubbl', 'buck', 'bucket', 'buckl', 'bud', 'budget', 'bueti', 'buff', 'buffalo', 'buffet', 'buffoon', 'bug', 'bugger', 'bugl', 'build', 'builder', 'built', 'bulb', 'bulg', 'bulk', 'bulki', 'bull', 'bullet', 'bulli', 'bum', 'bumbl', 'bump', 'bun', 'bunch', 'bundl', 'bungalow', 'bunk', 'bunker', 'bunni', 'buoy', 'buoyant', 'burb', 'burden', 'burdensom', 'bureau', 'bureaucrat', 'burger', 'burglar', 'burgundi', 'buri', 'burial', 'burn', 'burnish', 'burrow', 'burst', 'bus', 'buse', 'bush', 'bushi', 'busi', 'businessman', 'businessmen', 'busker', 'buss', 'bust', 'busti', 'bustl', 'busy', 'butch', 'butcher', 'butcheri', 'buti', 'butt', 'buttcrack', 'butter', 'buttercream', 'buttercup', 'butterfli', 'butterflywe', 'butteri', 'butterscotch', 'button', 'buy', 'buyer', 'buzz', 'buzzard', 'bye', 'bygon', 'bypass', 'cab', 'cabbag', 'cabin', 'cabinet', 'cabl', 'cabriol', 'cackl', 'cacophon', 'cacophoni', 'cactus', 'cadav', 'cael', 'caf', 'cafe', 'cafeteria', 'caffein', 'cage', 'cairo
'chill', 'chilli', 'chime', 'chimney', 'chin', 'china', 'chines', 'chink', 'chintz', 'chip', 'chipmunk', 'chirp', 'chisel', 'chivalr', 'chivalri', 'chive', 'chloe', 'chlorin', 'chock', 'chocol', 'choic', 'choir', 'choke', 'cholesterol', 'choos', 'choose', 'chop', 'chopper', 'choppi', 'chord', 'chore', 'choreograph', 'chortl', 'chorus', 'christ', 'christen', 'christma', 'chrome', 'chronic', 'chronicl', 'chrono', 'chronomet', 'chrysanthemum', 'chub', 'chubbi', 'chuck', 'chuckl', 'chunk', 'chunki', 'church', 'churchil', 'churchyard', 'churn', 'ciara', 'cicada', 'cicatric', 'cicatrix', 'cigar', 'cigarett', 'ciggi', 'cilantro', 'cinder', 'cinderella', 'cindi', 'cinnamon', 'circl', 'circuit', 'circul', 'circular', 'circumst', 'circus', 'citadel', 'citi', 'citizen', 'citizenri', 'civil', 'civilis', 'civillan', 'clack', 'claim', 'clair', 'clam', 'clamber', 'clammi', 'clamour', 'clamp', 'clandestin', 'clang', 'clangor', 'clank', 'clanker', 'clap', 'clara', 'clarabel', 'clare', 'clarif', 'clarissa', 'clariti', 'clark', 'clash', 'clasp', 'class', 'classic', 'classless', 'classmat', 'classroom', 'clatter', 'claus', 'claustrophob', 'claustrophobia', 'claw', 'clay', 'clean', 'cleaner', 'cleanli', 'cleans', 'clear', 'clearanc', 'cleat', 'cleav', 'cleave', 'cleaver', 'clement', 'clementin', 'clench', 'cleo', 'clergyman', 'cleric', 'clerk', 'clever', 'clich', 'click', 'client', 'cliff', 'climat', 'climax', 'climb', 'climber', 'cling', 'clingi', 'clinic', 'clink', 'clip', 'clipboard', 'cliqu', 'cliquey', 'cloak', 'cloakroom', 'clock', 'clockwork', 'clod', 'clog', 'cloister', 'clone', 'close', 'closer', 'closest', 'closet', 'closur', 'clot', 'cloth', 'clothe', 'cloud', 'cloudburst', 'cloudi', 'cloudless', 'clover', 'clown', 'cloy', 'club', 'clue', 'clump', 'clumsi', 'clunk', 'cluster', 'clutch', 'clutter', 'coach', 'coal', 'coars', 'coast', 'coaster', 'coastlin', 'coat', 'cobbl', 'cobbleston', 'cobhthach', 'cobra', 'cobweb', 'cock', 'cocki', 'cockpit', 'cocktail', 'coco', 'cocoa', 'coconut', 'cocoon', 'code', 'coffe', 'coffin', 'cog', 'cognac', 'cognit', 'cohes', 'cohort', 'coiffur', 'coil', 'coin', 'coke', 'col', 'cold', 'collaps', 'collar', 'colleagu', 'collect', 'collector', 'colleg', 'collid', 'collis', 'colloss', 'cologn', 'colon', 'coloni', 'colonialist', 'colonist', 'color', 'colorless', 'coloss', 'colour', 'columbia', 'columbian', 'column', 'comb', 'combat', 'combin', 'combo', 'combust', 'comed', 'comedi', 'comedian', 'comet', 'comfi', 'comfort', 'comic', 'comit', 'comm', 'command', 'commando', 'comment', 'commerci', 'commiss', 'commit', 'committe', 'commod', 'common', 'commune', 'communic', 'communism', 'communiti', 'commut', 'compact', 'compani', 'companion', 'companionship', 'compar', '
hime', 'hind', 'hinder', 'hindsight', 'hindu', 'hing', 'hint', 'hip', 'hippi', 'hippo', 'hire', 'hiss', 'histori', 'hit', 'hitch', 'hive', 'hmm', 'hmmm', 'ho', 'hoard', 'hoarder', 'hoax', 'hob', 'hobb', 'hobbi', 'hobbl', 'hogwart', 'hold', 'holden', 'holder', 'hole', 'holi', 'holiday', 'holler', 'holli', 'hollow', 'hollywood', 'holocaust', 'holster', 'homebodi', 'homeland', 'homeless', 'homemad', 'homeown', 'hometown', 'homework', 'homicid', 'hone', 'honest', 'honey', 'honk', 'honor', 'honour', 'hood', 'hoodi', 'hoof', 'hook', 'hooker', 'hooki', 'hoop', 'hoot', 'hoov', 'hoover', 'hop', 'hope', 'hopeless', 'hopscotch', 'horatio', 'hord', 'horizon', 'horizont', 'hormon', 'horn', 'hornet', 'horribl', 'horrif', 'horrifi', 'horror', 'hors', 'horseman', 'horsepow', 'horsesho', 'hose', 'hospit', 'host', 'hostil', 'hot', 'hotdog', 'hotel', 'hound', 'hour', 'hous', 'household', 'housekeep', 'housetop', 'housewif', 'houston', 'hovel', 'hover', 'howdi', 'howev', 'howl', 'hu', 'hubbub', 'huckleberri', 'huddl', 'hue', 'huff', 'huffi', 'hug', 'huge', 'hugh', 'hugo', 'huh', 'hulk', 'hull', 'hum', 'human', 'humanitarian', 'humber', 'humbl', 'humdrum', 'humid', 'hummus', 'humor', 'humour', 'hump', 'humung', 'hunch', 'hundr', 'hunger', 'hungri', 'hungrili', 'hunk', 'hunker', 'hunt', 'hunter', 'huntress', 'huntsman', 'hurl', 'hurri', 'hurrican', 'hurt', 'hurtl', 'husband', 'hush', 'husk', 'huski', 'hustl', 'hut', 'hydrant', 'hydrat', 'hydroplan', 'hymn', 'hyperinfl', 'hypertens', 'hypnot', 'hypnotis', 'hypoderm', 'hypotherm', 'hypoventil', 'hyster', 'hysteria', 'ian', 'ice', 'iceberg', 'iceland', 'ici', 'icicl', 'icon', 'idea', 'ideal', 'ident', 'identif', 'identifi', 'idioci', 'idiot', 'idl', 'idol', 'idyl', 'igloo', 'iglu', 'ignit', 'ignor', 'igor', 'ii', 'ikea', 'ill', 'illeg', 'illegitim', 'illog', 'illumin', 'illus', 'illustr', 'imag', 'imagin', 'imaginari', 'imbed', 'imbib', 'imit', 'immatur', 'immedi', 'immen', 'immens', 'immers', 'immigr', 'immobil', 'immor', 'immort', 'immov', 'immun', 'impact', 'impair', 'impal', 'impart', 'impass', 'impati', 'impend', 'impenetr', 'imper', 'impercept', 'imperfect', 'imperson', 'imperturb', 'impervi', 'impetu', 'impey', 'implac', 'implant', 'implement', 'import', 'importun', 'impos', 'imposs', 'impost', 'impostor', 'impress', 'imprint', 'imprison', 'improv', 'improvis', 'impuls', 'impur', 'inadequ', 'inan', 'inanim', 'inappropri', 'inaud', 'incalcul', 'incapacit', 'incarcer', 'incas', 'incendiari', 'incens', 'incent', 'incept', 'incess', 'inch', 'inciner', 'inclin', 'includ', 'incognito', 'incoher', 'incom
 'leash', 'leather', 'leatheri', 'leav', 'leave', 'lectur', 'ledg', 'lee', 'leech', 'leer', 'left', 'leftov', 'leg', 'legaci', 'legal', 'legalist', 'legend', 'legendari', 'legibl', 'legion', 'legisl', 'lego', 'leinster', 'leisur', 'lemna', 'lemon', 'lemonad', 'len', 'lend', 'length', 'lenni', 'lens', 'lentil', 'leo', 'leon', 'leroy', 'lessen', 'lesson', 'lethal', 'letter', 'letterbox', 'leupold', 'level', 'levi', 'levit', 'leviti', 'lex', 'lexi', 'li', 'liabl', 'liais', 'liam', 'liar', 'liber', 'liberti', 'librari', 'librarian', 'licens', 'lichen', 'lick', 'lid', 'lie', 'lieg', 'lietz', 'lieuten', 'life', 'lifeboat', 'lifeless', 'lifelong', 'lifespan', 'lifestyl', 'lifetim', 'lift', 'light', 'lighten', 'lighthead', 'lightn', 'lila', 'lilac', 'lili', 'lilli', 'lilt', 'limb', 'limit', 'limitless', 'limousin', 'limp', 'limpli', 'linen', 'liner', 'linger', 'lingeri', 'linguist', 'link', 'linoleum', 'lint', 'lintel', 'lion', 'lionel', 'lioness', 'lip', 'lipstick', 'liquid', 'liquor', 'liquoric', 'lisa', 'lissa', 'list', 'listen', 'listless', 'liter', 'literatur', 'lith', 'litig', 'litr', 'litter', 'littl', 'lival', 'live', 'liveli', 'liven', 'liverpool', 'livestock', 'liza', 'lizard', 'll', 'load', 'loaf', 'loam', 'loan', 'loath', 'lobbi', 'lobe', 'local', 'locat', 'lock', 'locker', 'locket', 'locomot', 'locust', 'lodg', 'loft', 'lofti', 'log', 'logic', 'lol', 'lola', 'loll', 'london', 'lone', 'loneli', 'lonesom', 'long', 'longboard', 'lookout', 'loom', 'loon', 'looney', 'loop', 'loopi', 'loos', 'loose', 'loosen', 'loot', 'looter', 'lopsid', 'lord', 'los', 'lose', 'loser', 'loss', 'lot', 'lotion', 'lotteri', 'loud', 'loui', 'loung', 'lousi', 'lovabl', 'love', 'loveabl', 'lover', 'low', 'lower', 'lowli', 'loyal', 'loyalti', 'lozeng', 'lsquo', 'luca', 'luci', 'lucilla', 'lucinda', 'luck', 'lucki', 'luckili', 'lucky', 'lug', 'luke', 'lukewarm', 'lull', 'lullabi', 'luma', 'lumber', 'lumin', 'luminesc', 'lump', 'lumpi', 'lumus', 'lunar', 'lunch', 'lunchroom', 'lung', 'lurch', 'lure', 'lurid', 'lurk', 'luscious', 'lush', 'lust', 'lustrous', 'lute', 'luxuri', 'lycra', 'lyric', 'mac', 'macca', 'machin', 'machineri', 'macho', 'maci', 'mad', 'madam', 'madden', 'mafia', 'magazin', 'magenta', 'maggi', 'maggot', 'magic', 'magician', 'magma', 'magnesium', 'magnet', 'magnifi', 'magnific', 'magnitud', 'magnolia', 'mahogani', 'maid', 'maiden', 'mail', 'mailbox', 'main', 'mainstream', 'maintain', 'mainten', 'maisi', 'maitr', 'majest', 'majesti', 'major', 'makeov', 'maker', 'makeshift', 'makeup', 'malcont', 'male', 'malevol', 'malfunct', 'malic', 'malici', 'malign', 'mall', 'malodor', 'malt', 'mam', 'mama', 'mamma', 'mammal', 'mammoth', 'man', 'manag', 'mandat', 'mandatori', 'mane', 'maneuv', 'mang', 'mangl', 'mangler', 'mango', 'mani', 'maniac', 'manic', 'manicur', 'manifest', 'manipul', 'mankind', 'mannequin', 'manner', 'manni', 'manoeuvr', 'manor', 'mansion', 'mantl', 'mantra', 'manual', 'manufactur', 'manur', 'map', 'mapl', 'mar', 'marathon', 'maraud', 'marbl', 'march', 'marci', 'marco', 'marcus', 'margin', 'mari', 'maria', 'mariah', 'marigold', 'marion', 'marissa', 'mark', 'marker', 'market', 'marketplac', 'marley', 'marlin', 'maroon', 'marqu', 'marri', 'marriag', 'marrow', 'marsh', 'marsha', 'marshmallow', 'martha', 'marvel', 'marvin', 'mascara', 'masculin', 'mask', 'mason', 'masonri', 'mass', 'massag', 'massingham', 'massiv', 'master', 'mastermind', 'masterpiec', 'mat', 'match', 'matchbook', 'matchstick', 'mate', 'mater', 'materi', 'matern', 'math', 'mathemat', 'mathematician', 'matilda', 'matron', 'matt', 'matter', 'matthew', 'mattress', 'matur', 'maud', 'mauser', 'mausoleum', 'mav', 'maverick', 'max', 'maxim', 'maximum', 'maxwel', 'maya', 'mayb', 'mayo', 'mayor', 'maywe', 'maze', 'mcdonald', 'mckay', 'mdash', 'mdf', 'meadow', 'meager', 'meagr', 'meal', 'mealtim', 'meander', 'meaning', 'meaningless', 'measur', 'meat', 'meati', 'mechan', 'med', 'medal', 'meddl', 'mediaev', 'medic', 'medicin', 'mediev', 'mediocr', 'medit', 'mediterranean', 'medium', 'meek', 'meet', 'megabit', 'megalomaniac', 'melamin', 'melanchol', 'melancholi', 'mellow', 'melod', 'melodi', 'melodrama', 'melt', 'melvin', 'member', 'membership', 'memo', 'memoir', 'memor', 'memori', 'men', 'menac', 'mend', 'menfolk', 'mental', 'mention', 'mento', 'mentor', 'menu', 'merced', 'merchandis', 'merchant', 'merci', 'merciless', 'mercuri', 'mere', 'merg', 'merilli', 'mermaid', 'merpeopl', 'merri', 'merrili', 'merritt', 'merriwel', 'mesmer', 'mess', 'messag', 'messeng', 'messi', 'metal', 'metamorphosi', 'metaphor', 'meter', 'method', 'metr', 'metropoli', 'metropolitan', 'mevelton', 'mexican', 'mi', 'mia', 'miami', 'mica', 'michael', 'michaelangelo', 'michaelma', 'mick', 'micro', 'microchip', 'microcosm', 'micromanag', 'microwav', 'mid', 'midday', 'middl', 'midg', 'midmorn', 'midnight', 'midsect', 'midst', 'midway', 'midwif', 'midwint', 'mighti', 'mighty', 'migrain', 'mike', 'mikka', 'mila', 'mild', 'mildew', 'mile', 'mileag', 'militari', 'milk', 'milki', 'milkman', 'mill', 'millennium', 'miller', 'millimetr', 'millpond', 'milo', 'mimic', 'mimick', 'mind', 'minded', 'mindless', 'mine', 'miner', 'mingl', 'mini', 'miniatur', 'minim', 'minimalist', 'minimum', 'minion', 'minist', 'minor', 'mint', 'minti', 'minuet', 'minus', 'minuscul', 'minut', 'mira', 'miracl', 'mirag', 'miranda', 'mire', 'mirror', 'mirth', 'mischief', 'mischiev', 'miscreant', 'misdirect', 'miser', 'miseri', 'misfortun', 'misinform', 'misinterpret', 'misjudg', 'mislead', 'misshapen', 'missil', 'mission', 'mist', 'mistak', 'mistake', 'misti', 'mistress', 'misunderstand', 'misus', 'mitt', 'mitten', 'mix', 'mixtur', 'mmm', 'mmmm', 'mo', 'moan', 'moat', 'mob', 'mobil', 'mobster', 'mock', 'mode', 'model', 'moder', 'modern', 'modernist', 'modest', 'modifi', 'modul', 'moist', 'moistur', 'molar', 'molass', 'mold', 'mole', 'molehil', 'mom', 'moment', 'momentari', 'momentarili', 'momento', 'momentum', 'momma', 'mommi', 'mon', 'mona', 'monarch', 'monarchi', 'monday', 'monet', 'money', 'monica', 'monitor', 'monkey', 'monochrom', 'monochromat', 'monocultur', 'monolith', 'monoton', 'monotoni', 'monsoon', 'monster', 'montag', 'month', 'monti', 'monument', 'mood', 'moon', 'moonless', 'moonlight', 'moonlit', 'moor', 'moorish', 'mop', 'moquett', 'moral', 'morbid', 'moreish', 'moreso', 'morgu', 'morn', 'moron', 'moros', 'morph', 'morphin', 'morri', 'morrison', 'morrow', 'mortal', 'mortar', 'mortgag', 'mortifi', 'mosaic', 'mosqu', 'mosquito', 'moss', 'mossi', 'motel', 'moth', 'mothbal', 'mother', 'motherboard', 'motion', 'motionless', 'motiv', 'motor', 'motorbik', 'motorcycl', 'motorist', 'motorway', 'mottl', 'motto', 'mould', 'mouldi', 'moult', 'mound', 'mount', 'mountain', 'mountainsid', 'mourn', 'mourner', 'mous', 'mousey', 'moustach', 'mouth', 'move', 'movement', 'movi', 'mow', 'mower', 'mp', 'ms', 'muck', 'mucki', 'mud', 'muddi', 'muddl', 'muddy', 'muffl', 'mugger', 'muggi', 'mulcair', 'mule', 'mull', 'mullion', 'multi', 'multipl', 'multipli', 'multitud', 'mum', 'mummi', 'munch', 'mundan', 'mural', 'murder', 'murki', 'murmur', 'murrey', 'muscl', 'muscular', 'muse', 'mush', 'mushi', 'mushroom', 'music', 'musician', 'musket', 'muski', 'muslim', 'mustard', 'muster', 'musti', 'mutat', 'mute', 'mutini', 'mutter', 'mutton', 'mutual', 'muzzl', 'myishi', 'myriad', 'mysteri', 'mystifi', 'myth', 'nacho', 'nacrin', 'nadin', 'nag', 'nail', 'naiv', 'naiveti', 'nake', 'nameless', 'nan', 'nana', 'nanci', 'nanna', 'nanni', 'nano', 'nanosecond', 'nap', 'nape', 'napkin', 'narcissist', 'narcot', 'narnia', 'narrow', 'narrowli', 'nasa', 'nascent', 'nasti', 'nasty', 'natalia', 'nathan', 'nation', 'natur', 'naturalist', 'naughti', 'nauseat', 'nauseous', 'nave', 'navel', 'navi', 'navig', 'nazi', 'ndash', 'neala', 'neanderth', 'nearbi', 'neat', 'necessari', 'neck', 'neckerchief', 'necklac', 'necklin', 'nectar', 'ned', 'needi', 'needl', 'needless', 'needn', 'negat', 'ne
ag', 'outright', 'outrun', 'outshin', 'outsid', 'outskirt', 'outstand', 'outstretch', 'outta', 'outward', 'outweigh', 'oval', 'oven', 'overal', 'overbear', 'overcast', 'overcoat', 'overcom', 'overcook', 'overcrowd', 'overdos', 'overdr', 'overdu', 'overeag', 'overflow', 'overgrow', 'overhang', 'overhead', 'overjoy', 'overlap', 'overload', 'overlook', 'overlord', 'overnight', 'overpass', 'overpow', 'overpr', 'overrun', 'overs', 'oversea', 'overshadow', 'oversight', 'overspil', 'overstock', 'overtak', 'overtake', 'overtim', 'overweight', 'overwhelm', 'overwork', 'ovoid', 'owe', 'owl', 'owner', 'ownership', 'ox', 'oxid', 'oxygen', 'oz', 'pace', 'pacif', 'pacifist', 'pack', 'packag', 'packet', 'pad', 'paddington', 'paddock', 'pagan', 'pageant', 'pail', 'pain', 'painkil', 'painless', 'painstak', 'paint', 'paintbrush', 'painter', 'paintwork', 'pair', 'pal', 'palac', 'palat', 'pale', 'palett', 'pall', 'pallid', 'palm', 'palpabl', 'pamper', 'pan', 'pancak', 'pane', 'panel', 'panic', 'panick', 'panorama', 'pansi', 'pant', 'panther', 'pantomim', 'papa', 'paper', 'paperback', 'paperi', 'paperweight', 'paperwork', 'papier', 'parabola', 'parachut', 'parad', 'paradis', 'paraffin', 'parallel', 'parallelogram', 'paralys', 'paralysi', 'paralyz', 'paramed', 'paranoia', 'paranoid', 'paraphernalia', 'parasit', 'parcel', 'parch', 'pardon', 'parent', 'pari', 'parish', 'parishion', 'parisian', 'park', 'parka', 'parker', 'parkland', 'parliament', 'parlour', 'parmesan', 'parol', 'paroxysm', 'parsley', 'parti', 'partial', 'particip', 'particl', 'partner', 'parvin', 'pas', 'pass', 'passag', 'passageway', 'passeng', 'passer', 'passion', 'passiv', 'passport', 'pasta', 'pastel', 'pastelli', 'pasti', 'pastim', 'pastor', 'pastri', 'pastur', 'pat', 'patch', 'patchwork', 'path', 'pathet', 'pathway', 'patienc', 'patient', 'patio', 'patricia', 'patrol', 'patter', 'pattern', 'patterson', 'paul', 'paulo', 'paunch', 'pauper', 'paus', 'pave', 'pavement', 'paw', 'pawn', 'pay', 'payer', 'payment', 'pea', 'peac', 'peach', 'peachi', 'peak', 'peal', 'pear', 'pearl', 'peasant', 'pebbl', 'peck', 'peculiar', 'pedagogu', 'pedal', 'pedant', 'peddl', 'pedest', 'pedestrian', 'pedicur', 'pee', 'peek', 'peekaboo', 'peel', 'peep', 'peer', 'pellet', 'pelt', 'pelvi', 'pen', 'penchant', 'pencil', 'penetr', 'penguin', 'peninsula', 'penni', 'pensiv', 'pentagon', 'peopl', 'pep', 'pepper', 'pepperi', 'perceiv', 'percent', 'percentag', 'percept', 'perch', 'percuss', 'perenni', 'perfect', 'perfection', 'perform', 'perfum', 'perfunctori', 'pergola', 'perhap', 'peril', 'perimet', 'period', 'peripher', 'perish', 'periwinkl', 'perk', 'permafrost', 'perman', 'permeat', 'permiss', 'permit', 'perpetu', 'perplex', 'persever', 'persist', 'person',
'samoan', 'samosa', 'sampl', 'samson', 'samurai', 'san', 'sanctuari', 'sand', 'sandal', 'sandbur', 'sandcastl', 'sander', 'sandi', 'sandston', 'sandwich', 'sane', 'sanguin', 'sanit', 'saniti', 'santa', 'sap', 'sapl', 'sapphir', 'sapphira', 'sappi', 'sara', 'sarah', 'saralina', 'sardon', 'sash', 'sasha', 'saskia', 'satan', 'satchel', 'sate', 'satellit', 'satin', 'satir', 'satisfact', 'satisfi', 'satur', 'saturday', 'sauc', 'saucer', 'sauer', 'saunter', 'sausag', 'savag', 'save', 'savil', 'savill', 'savior', 'saviour', 'savor', 'savour', 'savouri', 'sawdust', 'saxophon', 'scabbard', 'scale', 'scalp', 'scalpel', 'scam', 'scamper', 'scan', 'scandal', 'scandinavian', 'scanner', 'scanti', 'scapegoat', 'scar', 'scarc', 'scarciti', 'scare', 'scarf', 'scarfac', 'scari', 'scarlet', 'scarv', 'scary', 'scat', 'scath', 'scatter', 'scaveng', 'scenario', 'scene', 'sceneri', 'scenic', 'scent', 'schedul', 'scheme', 'schizophren', 'scholarship', 'school', 'schooler', 'schoolhous', 'schoolyard', 'schroding', 'scienc', 'scientif', 'scientist', 'scintil', 'scissor', 'scof', 'scold', 'sconc', 'scone', 'scoop', 'scope', 'scorch', 'score', 'scorn', 'scotland', 'scott', 'scottish', 'scour', 'scout', 'scowl', 'scrabbl', 'scram', 'scrambl', 'scrap', 'scrape', 'scraper', 'scratch', 'scrawl', 'scrawni', 'scream', 'scree', 'screech', 'screeeiiigh', 'screen', 'screw', 'scribbl', 'script', 'scriptur', 'scrollwork', 'scrub', 'scrubbi', 'scrupul', 'scrutin', 'scrutini', 'scud', 'scuf', 'scuff', 'scuffl', 'sculpt', 'sculptur', 'scum', 'scurri', 'scuttl', 'scyth', 'sea', 'seafood', 'seafront', 'seagul', 'seal', 'seam', 'seaman', 'seamless', 'sean', 'sear', 'search', 'seashel', 'seasid', 'season', 'seat', 'seatbelt', 'seawe', 'seb', 'sebastian', 'seclud', 'seclus', 'second', 'secondari', 'secondhand', 'secret', 'secretari', 'secular', 'secur', 'secutor', 'sedan', 'sedat', 'sediment', 'sediti', 'seduct', 'seed', 'seedl', 'seek', 'seeker', 'seep', 'seeth', 'sein', 'seiz', 'seldom', 'select', 'selfi', 'selfish', 'selfless', 'selina', 'sell', 'seller', 'selv', 'semblanc', 'semi', 'send', 'sender', 'senior', 'senitel', 'sens', 'sensat', 'senseless', 'sensibl', 'sensit', 'sensor', 'sensori', 'sentenc', 'sentient', 'sentiment', 'sentinel', 'separ', 'sepia', 'septemb', 'sequenc', 'sequin', 'seren', 'serenad', 'seri', 'serious', 'sermon', 'serpent', 'serrat', 'serv', 'servant', 'server', 'servic', 'servitud', 'session', 'set', 'settl', 'seventeen', 'seventi', 'sever', 'severin', 'sew', 'sewag', 'sewer', 'sex', 'sexi', 'sexism', 'sexual', 'shaan', 'shabbi', 'shack', 'shackl', 'shade', 'shadi', 'shadow', 'shadowi', 'shadowless', 
ot', 'sloth', 'slough', 'slow', 'slowcoach', 'slowli', 'sluggish', 'slum', 'slumber', 'slump', 'slung', 'slur', 'slurpe', 'slush', 'slushi', 'slyli', 'smack', 'small', 'smart', 'smash', 'smatter', 'smear', 'smell', 'smelli', 'smelt', 'smidg', 'smile', 'smiler', 'smirk', 'smite', 'smithereen', 'smock', 'smog', 'smoke', 'smoker', 'smokey', 'smoki', 'smolder', 'smoosh', 'smooth', 'smoothi', 'smother', 'smoulder', 'smudg', 'smudgi', 'smug', 'smuggl', 'smuggler', 'snack', 'snag', 'snail', 'snake', 'snaki', 'snap', 'snapshot', 'snare', 'snarl', 'snatch', 'sneak', 'sneaker', 'sneer', 'sneez', 'snicker', 'snif', 'sniff', 'sniffer', 'sniffl', 'sniper', 'snitch', 'snob', 'snooz', 'snore', 'snort', 'snot', 'snout', 'snow', 'snowbal', 'snowboard', 'snowdrift', 'snowfal', 'snowflak', 'snowi', 'snowmageddon', 'snowman', 'snowmobil', 'snowpack', 'snowstorm', 'snub', 'snuf', 'snug', 'snuggl', 'soak', 'soap', 'soapi', 'soar', 'sob', 'sober', 'soccer', 'social', 'societ', 'societi', 'sociopath', 'sock', 'socket', 'sod', 'soda', 'sodden', 'soft', 'soften', 'softwar', 'soggi', 'soil', 'solac', 'solar', 'soldier', 'sole', 'solemn', 'solid', 'solidifi', 'solitari', 'solitud', 'solo', 'solut', 'solv', 'somber', 'sombr', 'somebodi', 'someday', 'someon', 'somersault', 'somerset', 'someth', 'sometim', 'somewher', 'somnol', 'son', 'song', 'sooner', 'sooth', 'sooti', 'sop', 'sophi', 'sophist', 'sophomor', 'soppi', 'sore', 'sorri', 'sorrow', 'sort', 'souffl', 'soul', 'soulless', 'soulmat', 'sound', 'soundless', 'soundtrack', 'soup', 'soupi', 'sour', 'sourc', 'souri', 'south', 'southern', 'sow', 'sp', 'spa', 'space', 'spacecraft', 'spaceship', 'spacious', 'spade', 'spaghetti', 'spain', 'span', 'spandex', 'spangl', 'spaniel', 'spar', 'spare', 'spark', 'sparkl', 'sparrow', 'spars', 'spartancav', 'spasm', 'spat', 'spatter', 'spawn', 'speak', 'speaker', 'spear', 'spec', 'speci', 'special', 'specialist', 'specif', 'specimen', 'speck', 'speckl', 'spectacl', 'spectacular', 'spectr', 'spectrum', 'specul', 'speech', 'speechless', 'speed', 'speedi', 'spell', 'spellbound', 'spend', 'spew', 'sphere', 'spi', 'spice', 'spici', 'spider', 'spike', 'spill', 'spin', 'spinach', 'spinal', 'spind', 'spindl', 'spine', 'spineless', 'spinney', 'spiral', 'spire', 'spirit', 'spiritu', 'spit', 'spite', 'spittl', 'splash', 'splatter', 'splendid', 'splendour', 'splice', 'splint', 'splinter', 'split', 'splotch', 'splutter', 'spoil', 'spong', 'spongey', 'spongi', 'sponsor', 'spontan', 'spook', 'spooki', 'spoon', 'sporad', 'spore', 'spork', 'sport', 'sporti', 'spot', 'spotless', 'spotlight', 'spotti', 'spous', 'spout', 'sprawl', 'spray', 'sprayer', 'spread', 'spree', 'spri', 'sprig', 'spring', 'springi', 'springtim', 'sprinkl', 'sprint', 'sprite', 'sprout', 'spruce', 'spume', 'spunki', 'spurt', 'sputter', 'sqaur', 'sqeal', 'squabbl', 'squad', 'squalid', 'squall', 'squalor', 'squander', 'squar', 'squarish', 'squash', 'squat', 'squattish', 'squawk', 'squeak', 'squeaki', 'squeal', 'squeez', 'squelch', 'squid', 'squint', 'squirm', 'squirrel', 'squirt', 'squish', 'squishi', 'st', 'stab', 'stabil', 'stabl', 'stacey', 'stack', 'stadium', 'staf', 'staff', 'stage', 'stagger', 'stagnant', 'stagnat', 'stain', 'stainless', 'stair', 'staircas', 'stake', 'stalactit', 'stalagmit', 'stale', 'stalin', 'stalk', 'stalker', 'stall', 'stallion', 'stammer', 'stamp', 'stamped', 'stand', 'standard', 'stapl', 'star', 'starboard', 'starbuck', 'starburst', 'starch', 'starchi', 'stare', 'starfish', 'stark', 'starless', 'starlet', 'starlight', 'start', 'startl', 'starv', 'starvat', 'stash', 'state', 'statement', 'static', 'station', 'stationari', 'statist', 'statu', 'status', 'statut', 'stave', 'stay', 'stead', 'steadfast', 'steadi', 'steadili', 'steak', 'steal', 'stealth', 'steam', 'steamroom', 'steed', 'steel', 'steeli', 'steep', 'steepl', 'steepli', 'steer', 'stem', 'stench', 'stencil', 'step', 'stepbroth', 'stephani', 'stereotyp', 'steril', 'stern', 'stethoscop', 'steve', 'steven', 'stevenson', 'stew', 'steward', 'stewardess', 'stick', 'sticker', 'sticki', 'stiff', 'stiffen', 'stiffl', 'stiffli', 'stifl', 'stile', 'stiletto', 'stilt', 'stimul', 'sting', 'stink', 'stinki', 'stir', 'stitch', 'stock', 'stocki', 'stockpil', 'stoic', 'stoicism', 'stoke', 'stomach', 'stomp', 'stone', 'stonewal', 'stonework', 'stoney', 'stoni', 'stoog', 'stool', 'stoop', 'storag', 'store', 'storey', 'stori', 'storm', 'stormdrain', 'stormi', 'storybook', 'storytel', 'stow', 'stragg', 'straggler', 'straight', 'straighten', 'strain', 'strand', 'strang', 'strange', 'stranger', 'strangl', 'stranglehold', 'strap', 'strategi', 'stratospher', 'stratus', 'straw', 'strawberri', 'stray', 'streak', 'stream', 'streamer', 'streami', 'street', 'streetlamp', 'streetlight', 'strength', 'strengthen', 'stress', 'stretch', 'stretcher', 'strew', 'striation', 'stricken', 'strict', 'stride', 'strike', 'string', 'strip', 'stripe', 'strive', 'strobe', 'stroke', 'stroll', 'stroller', 'strong', 'structur', 'struggl', 'strut', 'stuart', 'stubbi', 'stubbl', 'stubborn', 'stucco', 'stuck', 'student', 'studi', 'studious', 'stuf', 'stuff', 'stuffi', 'stumbl', 'stump', 'stun', 'stunt', 'stupid', 'style', 'stylish', 'subconsci', 'subdu', 'subject', 'subjug', 'sublim', 'sublimin', 'submarin', 'submerg', 'submers', 'submiss', 'submit', 'subordin', 'subscrib', 'subsect', 'subservi', 'subsid', 'subsist', 'substanc', 'substanti', 'subterranean', 'subtl', 'subtrop', 'suburb', 'suburban', 'suburbia', 'subway', 'subzero', 'succeed', 'success', 'succul', 'succumb', 'suck', 'sucker', 'sudden', 'sue', 'suffer', 'suffici', 'suffoc', 'sugar', 'suicid', 'suit', 'suitabl', 'sulk', 'sulphur', 'sultri', 'sum', 'summer', 'summeri', 'summertim', 'summit', 'summon', 'sumptuous', 'sun', 'sunbeam', 'sunburn', 'sunburnt', 'sunday', 'sundown', 'sunflow', 'sunglass', 'sunken', 'sunless', 'sunlight', 'sunni', 'sunray', 'sunris', 'sunset', 'sunshin', 'sunshini', 'suntan', 'super', 'superc', 'superflu', 'superglu', 'superior', 'supermarket', 'superpow', 'superstar', 'supervillain', 'supervis', 'supin', 'supper', 'suppl', 'suppli', 'support', 'suppos', 'suppress', 'supress', 'sur', 'sure', 'sureti', 'surf', 'surfac', 'surg', 'surgeon', 'surgeri', 'surgic', 'suri', 'surmis', 'surpass', 'surplus', 'surpris', 'surreal', 'surrend', 'surround', 'surveil', 'survey', 'surviv', 'survivor', 'susan', 'suspect', 'suspend', 'suspens', 'suspici', 'suspicion', 'suss', 'sussur', 'sustain', 'susurr', 'suv', 'swagger', 'swallow', 'swamp', 'swan', 'swap', 'swarm', 'swarthi', 'swat', 'swath', 'sway', 'swear', 'sweat', 'sweater', 'sweati', 'sweatier', 'sweep', 'sweeper', 'sweet', 'sweetheart', 'swell', 'swelter', 'swerv', 'swift', 'swim', 'swimmer', 'swing', 'swipe', 'swirl', 'swish', 'swiss', 'switch', 'swivel', 'swoop', 'swoosh', 'sword', 'swordsman', 'swot', 'sycamor', 'sydn', 'sydney', 'syke', 'syllabl', 'symbol', 'symmetr', 'symmetri', 'sympath', 'sympathet', 'sympathi', 'symphoni', 'synaps', 'synchron', 'syrup', 'system', 't', 'tab', 'tabi', 'tabitha', 'tabl', 'tablecloth', 'tablet', 'tabloid', 'tacit', 'tack', 'tacki', 'tackl', 'taco', 'tact', 'tactic', 'tad', 'tag', 'taggl', 'tagliatell', 'tail', 'tailor', 'taint', 'takehashi', 'taker', 'taksheel', 'tale', 'talent', 'talk', 'tall', 'talli', 'talon', 'tamal', 'tame', 'tan', 'tandem', 'tang', 'tangerin', 'tangi', 'tangibl', 'tangl', 'tango', 'tank', 'tanner', 'tannoy', 'tantal', 'tantamount', 'tantrum', 'tanuvia', 'tanya', 'tap', 'tape', 'taper', 'tapestri', 'tar', 'tara', 'tarant', 'tarantula', 'target', 'tarken', 'tarmac', 'tarnish', 'tart', 'taser', 'task', 'tassel', 'tast', 'tastebud', 'tasteless', 'taster', 'tasti', 'tat', 'tatter', 'tatti', 'tattoo', 'taunt', 'taup', 'tavern', 'tawni', 'tax', 'taxi', 'taxicab', 'taxman', 'taylor', 'tea', 'teach', 'teacher', 'teal', 'team', 'teapot', 'tear', 'teardrop', 'teas', 'tech', 'technic', 'technician', 'techniqu', 'technolog', 'ted', 'teddi', 'tedious', 'tedium', 'teela', 'teem', 'teen', 'teenag', 'teeth', 'telanara', '
 'tram', 'trampl', 'tranc', 'tranquil', 'tranquillis', 'transcend', 'transcript', 'transfer', 'transfix', 'transform', 'transgress', 'transient', 'transit', 'transitori', 'transluc', 'transmiss', 'transmit', 'transpar', 'transpond', 'transport', 'transpos', 'trap', 'trapdoor', 'trash', 'trask', 'trauma', 'traumat', 'travel', 'travers', 'travertin', 'travi', 'tray', 'treacher', 'treacl', 'tread', 'treasur', 'treat', 'treatabl', 'treatment', 'trebutchet', 'tree', 'treeless', 'treetop', 'trek', 'trembl', 'tremend', 'tremor', 'trench', 'trend', 'trendi', 'tress', 'trevor', 'tri', 'triag', 'trial', 'tribut', 'trick', 'tricki', 'trickl', 'trident', 'triffid', 'trigger', 'trigonometri', 'trill', 'trim', 'trina', 'trip', 'tripl', 'triumph', 'triumphant', 'trivial', 'troll', 'trolley', 'trolli', 'troop', 'tropic', 'trot', 'troubl', 'troublesom', 'trough', 'trouser', 'trout', 'troy', 'truck', 'trudg', 'true', 'truffl', 'truli', 'trumpet', 'truncat', 'trundl', 'trunk', 'truss', 'trust', 'trustworthi', 'truth', 'tsunami', 'tub', 'tube', 'tuck', 'tudor', 'tuesday', 'tuft', 'tug', 'tulip', 'tulli', 'tumbl', 'tummi', 'tumult', 'tumultu', 'tune', 'tunic', 'tunnel', 'tupperwar', 'turbul', 'tureen', 'turf', 'turkey', 'turn', 'turnip', 'turquois', 'turret', 'turtl', 'tussl', 'tussock', 'tut', 'tutelag', 'tutor', 'tv', 'tweak', 'tweedi', 'tweet', 'twelv', 'twenti', 'twerp', 'twig', 'twilight', 'twin', 'twine', 'twinkl', 'twirl', 'twist', 'twister', 'twitch', 'twitter', 'tyler', 'type', 'typic', 'tyre', 'ubiquit', 'ughter', 'ugli', 'ultim', 'umbrella', 'unabash', 'unabl', 'unabus', 'unaccustom', 'unadorn', 'unafraid', 'unaid', 'unalt', 'unapologet', 'unarm', 'unassist', 'unassum', 'unawar', 'unbalanc', 'unbash', 'unbear', 'unbeliev', 'unbind', 'unbleach', 'unblink', 'unborn', 'unbreak', 'unbroken', 'unburi', 'unbutton', 'uncar', 'unceas', 'unceremoni', 'uncertainti', 'unchang', 'unchart', 'uncheck', 'uncl', 'unclutt', 'uncollect', 'uncomb', 'uncomfort', 'uncondit', 'unconsci', 'unconscion', 'uncontrol', 'unconvinc', 'uncount', 'uncouth', 'uncov', 'uncurl', 'uncut', 'undaunt', 'undead', 'undecid', 'undemand', 'undeni', 'underag', 'underarm', 'underbelli', 'underbrush', 'undercoat', 'undercurr', 'underfloor', 'underfoot', 'underfund', 'underground', 'undergrowth', 'underneath', 'underpay', 'underpin', 'underscor', 'undersid', 'underst', 'understand', 'understat', 'underton', 'underturn', 'underwat', 'underwear', 'underwhelm', 'undesir', 'undetect', 'undi', 'undiscov', 'undistinguish', 'undisturb', 'undo', 'undocu', 'undon', 'undoubt', 'undrink', 'undul', 'une', 'unearn', 'unearth', 'uneasi', 'uneasili', 'unemploy', 'unend', 'uneven', 'unexpect', 'unexplain', 'unfair', 'unfalt', 'unfamiliar', 'unfashion', 'unfeel', 'unfett', 'unfilt', 'unfinish', 'unfit', 'unflex', 'unflinch', 'unfocus', 'unfold', 'unforgett', 'unforgiv', 'unforgiving', 'unfortun', 'unfriend', 'unfulfil', 'unfurl', 'unfussi', 'ungener', 'unglov', 'ungod', 'unguard', 'unhappi', 'unhealthi', 'unheard', 'unhelp', 'unhind', 'unholi', 'unhurri', 'uni', 'unifi', 'uniform', 'unimagin', 'unimpress', 'uninhabit', 'unintent', 'uninterrupt', 'union', 'uniqu', 'unison', 'unit', 'uniti', 'univers', 'unkempt', 'unknow', 'unknown', 'unladylik', 'unleash', 'unlik', 'unlimit', 'unlock', 'unlov', 'unlucki', 'unmad', 'unmark', 'unmeasur', 'unmelt', 'unmov', 'unmown', 'unnam', 'unnatur', 'unnecessari', 'unnerv', 'unnot', 'unoccupi', 'unpaint', 'unpav', 'unpleas', 'unpolish', 'unpredict', 'unprosper', 'unprotect', 'unquest', 'unravel', 'unread', 'unreadi', 'unreason', 'unrecogniz', 'unregard', 'unregist', 'unregul', 'unrel', 'unrestrain', 'unrins', 'unrival', 'unruli', 'unsay', 'unscrupul', 'unseen', 'unselfish', 'unsettl', 'unshak', 'unshap', 'unshield', 'unsmil', 'unsmudg', 'unsoften', 'unspoil', 'unspoilt', 'unstabl', 'unsteadili', 'unstop', 'unstopp', 'unsubdu', 'unsubtl', 'unsuccess', 'unsur', 'unsuspect', 'untam', 'untap', 'untarnish', 'unthink', 'unti', 'untidi', 'untold', 'untouch', 'untreat', 'untrendi', 'untrodden', 'untrustworthi', 'unus', 'unusu', 'unveil', 'unwant', 'unwash', 'unwav', 'unweed', 'unweep', 'unwelcom', 'unwil', 'unwind', 'unworthi', 'unwrap', 'unyield', 'upbeat', 'upbring', 'upcom', 'updraft', 'uped', 'upend', 'upgrad', 'upholsteri', 'upkeep', 'uplift', 'upmost', 'upper', 'upright', 'uproar', 'uproari', 'uproot', 'upset', 'upsid', 'upsoar', 'upstair', 'uptown', 'upward', 'urban', 'urbanis', 'urg', 'urin', 'urn', 'usag', 'useless', 'usher', 'usual', 'usurp', 'utensil', 'util', 'utilitarian', 'utopia', 'utter', 'vacant', 'vacat', 'vaccin', 'vacuum', 'vagu', 'vain', 'vale', 'valentin', 'valiant', 'valium', 'valley', 'valu', 'valuabl', 'van', 'vancouv', 'vane', 'vanilla', 'vanish', 'vaniti', 'vantag', 'vapid', 'vapor', 'vapour', 'vari', 'variat', 'varieg', 'varieti', 'varnish', 'varsiti', 'vase', 'vast', 'vault', 've', 'veer', 'vega', 'veget', 'vehicl', 'veil', 'vein', 'veldt', 'veloc', 'velvet', 'velveti', 'vend', 'vendor', 'veneer', 'veng', 'vengeanc', 'venom', 'vent', 'ventil', 'ventur', 'vera', 'verac', 'veranda', 'verandah', 'verdant', 'verdict', 'verg', 'veri', 'verona', 'version', 'vertebra', 'vertic', 'vessel', 'vest', 'vestri', 'veteran', 'veterinari', 'vex', 'vibranc', 'vibrant', 'vibrat', 'vicar', 'vicarag', 'vicari', 'vicin', 'vicious', 'victim', 'victimhood', 'victor', 'victori', 'victorian', 'video', 'view', 'viewer', 'vigor', 'vile', 'vilif', 'villa', 'villag', 'villain', 'vincent', 'vindic', 'vine', 'vinni', 'vintag', 'vinyl', 'violat', 'violenc', 'violent', 'violet', 'violin', 'viper', 'viral', 'viresc', 'virgin', 'virtu', 'virtuous', 'virus', 'visibl', 'vision', 'visionari', 'visit', 'visitor', 'vista', 'vital', 'vivac', 'vivaci', 'vivid', 'vivr', 'vocabulari', 'vocal', 'vodka', 'vogu', 'voic', 'void', 'volatil', 'volcan', 'volcano', 'volt', 'volubl', 'volum', 'volumin', 'volunt', 'volvo', 'vomit', 'von', 'vortex', 'vortic', 'vote', 'vous', 'vow', 'voyag', 'vulgar', 'vulner', 'vy', 'wa', 'wad', 'wade', 'wafer', 'waffl', 'waft', 'wag', 'wage', 'waif', 'wail', 'waist', 'waistband', 'waistcoat', 'waistlin', 'wait', 'waiter', 'waitin', 'waitress', 'wake', 'waken', 'walk', 'walker', 'walkur', 'walkway', 'wall', 'wallac', 'wallet', 'wallop', 'wallow', 'wallpap', 'walnut', 'waltz', 'wan', 'wand', 'wander', 'wane', 'wanna', 'wanton', 'war', 'warbl', 'ward', 'wardrob', 'ware', 'warehous', 'warfar', 'warhead', 'wari', 'warlord', 'warm', 'warmer', 'warmth', 'warn', 'warp', 'warrant', 'warren', 'warrior', 'wash', 'washroom', 'washstand', 'wasn', 'wasp', 'wast', 'wasteland', 'watch', 'watcher', 'water', 'watercolour', 'waterfal', 'wateri', 'waterlog', 'waterproof', 'watership', 'waterway', 'watt', 'waugh', 'wave', 'waver', 'wavi', 'wax', 'waxi', 'wayward', 'weak', 'weaken', 'wealth', 'wealthi', 'weapon', 'weaponri', 'wear', 'weari', 'weather', 'weatherman', 'weav', 'weave', 'weaver', 'web', 'webcast', 'websit', 'wedg', 'wednesday', 'wee', 'weed', 'weedi', 'week', 'weekend', 'weep', 'weeper', 'weetabix', 'weigh', 'weight', 'weighti', 'weightless', 'weimar', 'weird', 'welcom', 'weld', 'well', 'wellb', 'welt', 'wend', 'weren', 'werewolf', 'west', 'western', 'wet', 'whack', 'whale', 'whatev', 'wheat', 'whebi', 'wheel', 'wheelbarrow', 'wheelchair', 'wheez', 'whenev', 'wher', 'wherea', 'whereabout', 'wherev', 'whi', 'whichev', 'whiff', 'whilst', 'whimper', 'whimsic', 'whine', 'whini', 'whip', 'whir', 'whirl', 'whirlwind', 'whisk', 'whisker', 'whiskeri', 'whiskey', 'whiski', 'whisper', 'whistl', 'white', 'whiten', 'whitish', 'whitney', 'whittl', 'whizz', 'wholesom', 'wholli', 'whomev', 'whoop', 'whoosh', 'wick', 'wicker', 'wide', 'widen', 'widow', 'width', 'wield', 'wife', 'wifi', 'wig', 'wigg', 'wiggl', 'wild', 'wilder', 'wildfir', 'wildlif', 'will', 'william', 'willow', 'willowi', 'wilt', 'win', 'winc', 'winch', 'winchfield', 'wind', 'windi', 'windless', 'windmil', 'window', 'windowless', 'windowsil', 'windscreen', 'windshield', 'windswept', 'wine', 'wing', 'wink', 'winner', 'winnow', 'winston', 'winter', 'winteri', 'wintri', 'wipe', 'wiper', 'wire', 'wireless', 'wiri', 'wisdom', 'wise', 'wisp', 'wispi', 'wist', 'wit', 'witch', 'witchcraft', 'withal', 'withdraw', 'wither', 'withstand', 'witti', 'wive', 'wizard', 'wizen', 'wobbl', 'woe', 'wolf', 'wolv', 'woman', 'womb', 'women', 'wonder', 'wonderland', 'wondrous', 'woner', 'wood', 'wooden', 'woodi', 'woodland', 'wool', 'woolen', 'wooli', 'woollen', 'word', 'wordless', 'wordsmith', 'work', 'workbench', 'worker', 'workout', 'workshop', 'worm', 'worri', 'worrisom', 'wors', 'worsen', 'worship', 'worst', 'worth', 'worthi', 'worthless', 'wouldn', 'wound', 'wow', 'wrack', 'wrap', 'wrapper', 'wrath', 'wreath', 'wreck', 'wreckag', 'wrench', 'wrest', 'wrestl', 'wretch', 'wri', 'wriggl', 'wring', 'wrinkl', 'wrist', 'write', 'writer', 'writh', 'written', 'wrong', 'wrongdo', 'wur', 'xxx', 'ya', 'yacht', 'yamaha', 'yank', 'yanke', 'yap', 'yappi', 'yard', 'yarn', 'yawn', 'yeah', 'year', 'yearn', 'yell', 'yellow', 'yellowish', 'yelp', 'yep', 'yesterday', 'yesteryear', 'yew', 'yield', 'ymir', 'yo', 'yoga', 'yoghurt', 'yolk', 'york', 'young', 'younger', 'youngster', 'yourselv', 'youth', 'yum', 'yummi', 'yup', 'yuppi', 'zac', 'zapinof', 'zen', 'zenith', 'zigzag', 'zip', 'ziplocon', 'zipper', 'zircon', 'zit', 'zoe', 'zombi', 'zombifi', 'zone', 'zoo', 'zoom']

# %%
print(Vocab)
# Out:
# ['aa', 'aadila', 'aaron', 'aback', 'abandon', 'abdomen', 'abduct', 'abid', 'abil', 'abject', 'abl', 'abnorm', 'aboard', 'abod', 'abomin', 'abound', 'abour', 'abov', 'abraham', 'abras', 'abroad', 'abrupt', 'absenc', 'absent', 'absolut', 'absorb', 'absorpt', 'abstract', 'absurd', 'abund', 'abus', 'aby', 'abysm', 'academ', 'academi', 'acajou', 'acceler', 'accent', 'accentu', 'accept', 'access', 'accid', 'accommod', 'accompani', 'accomplic', 'accomplish', 'accord', 'account', 'accross', 'accru', 'accumul', 'accur', 'accus', 'accustom', 'ace', 'ach', 'achiev', 'acid', 'acknowledg', 'acn', 'acorn', 'acquiesc', 'acquir', 'acr', 'acrid', 'acryl', 'action', 'activ', 'actor', 'actual', 'acut', 'ad', 'adam', 'adapt', 'add', 'addict', 'addit', 'addl', 'address', 'ade', 'adequ', 'adhes', 'adjac', 'adjoin', 'adjust', 'administr', 'admir', 'admiss', 'admit', 'admitt', 'adopt', 'ador', 'adorn', 'adrenalin', 'adrift', 'adult', 'adulthood', 'advanc', 'advantag', 'adventur', 'adversari', 'advert', 'adv
# ...
